# %%
from ultralytics import YOLO
import numpy as np
import cv2
import matplotlib.pyplot as plt
from utils import processing
import os
import shutil
import itertools

# %%
# model = YOLO("yolo_model/yolo11n-obb.pt")

# %%
# result = model.train(data="data.yaml", epochs=200, batch=16, imgsz=640, patience=10, degrees=30.0, flipud=0.5, fliplr=0.5)
# Out:
# New https://pypi.org/project/ultralytics/8.3.40 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.31  Python-3.10.15 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# engine\trainer: task=obb, mode=train, model=yolo_model/yolo11n-obb.pt, data=data.yaml, epochs=200, time=None, patience=10, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train6, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=30.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.5, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\obb\train6
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    502534  ultralytics.nn.modules.head.OBB              [1, 1, [64, 128, 256]]
# YOLO11n-obb summary: 344 layers, 2,661,702 parameters, 2,661,686 gradients, 6.7 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\obb\train6', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Scanning C:\Dataset\card\datasets\train\labels.cache... 1600 images, 0 backgrounds, 78 corrupt: 100%|██████████| 1600/1600 [00:00<?, ?it/s]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1058.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.006]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1069.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.034]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1070.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.005]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1087.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.051]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1108.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.034]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1110.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.025]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1219.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.043]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1259.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.013]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1326.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.032]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1327.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.025]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1339.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.029]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1340.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.292]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1369.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1371.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.088]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1372.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.081]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1373.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.103]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1375.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1376.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.005]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1377.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.049]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1378.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.05]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1379.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.075]
# train: WARNING  C:\Dataset\card\datasets\train\images\image138.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.027]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1380.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.169]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1419.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.05]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1420.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.043]
# train: WARNING  C:\Dataset\card\datasets\train\images\image15.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.032]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1533.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.036]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1534.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.058]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1540.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.134]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1549.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.038]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1550.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.011]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1554.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.001]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1567.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1568.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.006]
# train: WARNING  C:\Dataset\card\datasets\train\images\image166.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.012]
# train: WARNING  C:\Dataset\card\datasets\train\images\image167.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.045]
# train: WARNING  C:\Dataset\card\datasets\train\images\image168.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.018]
# train: WARNING  C:\Dataset\card\datasets\train\images\image169.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.037]
# train: WARNING  C:\Dataset\card\datasets\train\images\image170.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.07]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1764.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.013]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1778.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.086]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1779.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.117]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1807.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.031]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1808.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.021]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1809.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.005]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1816.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.044]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1817.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.018]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1828.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.008]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1829.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.012]
# train: WARNING  C:\Dataset\card\datasets\train\images\image1977.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.093]
# train: WARNING  C:\Dataset\card\datasets\train\images\image218.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.019]
# train: WARNING  C:\Dataset\card\datasets\train\images\image333.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.058]
# train: WARNING  C:\Dataset\card\datasets\train\images\image334.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.079]
# train: WARNING  C:\Dataset\card\datasets\train\images\image388.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.051]
# train: WARNING  C:\Dataset\card\datasets\train\images\image408.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.046]
# train: WARNING  C:\Dataset\card\datasets\train\images\image409.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.045]
# train: WARNING  C:\Dataset\card\datasets\train\images\image416.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.237]
# train: WARNING  C:\Dataset\card\datasets\train\images\image417.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.025]
# train: WARNING  C:\Dataset\card\datasets\train\images\image430.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.001]
# train: WARNING  C:\Dataset\card\datasets\train\images\image451.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.034]
# train: WARNING  C:\Dataset\card\datasets\train\images\image453.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.009]
# train: WARNING  C:\Dataset\card\datasets\train\images\image568.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.021]
# train: WARNING  C:\Dataset\card\datasets\train\images\image581.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.006]
# train: WARNING  C:\Dataset\card\datasets\train\images\image60.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.037]
# train: WARNING  C:\Dataset\card\datasets\train\images\image628.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.015]
# train: WARNING  C:\Dataset\card\datasets\train\images\image629.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.02]
# train: WARNING  C:\Dataset\card\datasets\train\images\image650.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.041]
# train: WARNING  C:\Dataset\card\datasets\train\images\image656.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.026]
# train: WARNING  C:\Dataset\card\datasets\train\images\image698.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.039]
# train: WARNING  C:\Dataset\card\datasets\train\images\image699.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.006]
# train: WARNING  C:\Dataset\card\datasets\train\images\image700.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.017]
# train: WARNING  C:\Dataset\card\datasets\train\images\image708.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.017]
# train: WARNING  C:\Dataset\card\datasets\train\images\image709.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.025]
# train: WARNING  C:\Dataset\card\datasets\train\images\image710.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.011]
# train: WARNING  C:\Dataset\card\datasets\train\images\image779.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.118]
# train: WARNING  C:\Dataset\card\datasets\train\images\image967.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.01]
# train: WARNING  C:\Dataset\card\datasets\train\images\image968.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.011]
# train: WARNING  C:\Dataset\card\datasets\train\images\image988.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.017]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning C:\Dataset\card\datasets\val\labels.cache... 400 images, 0 backgrounds, 14 corrupt: 100%|██████████| 400/400 [00:00<?, ?it/s]
# val: WARNING  C:\Dataset\card\datasets\val\images\image1047.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.032]
# val: WARNING  C:\Dataset\card\datasets\val\images\image1048.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.122]
# val: WARNING  C:\Dataset\card\datasets\val\images\image1088.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.06]
# val: WARNING  C:\Dataset\card\datasets\val\images\image1374.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.067]
# val: WARNING  C:\Dataset\card\datasets\val\images\image1777.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.043]
# val: WARNING  C:\Dataset\card\datasets\val\images\image228.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.026]
# val: WARNING  C:\Dataset\card\datasets\val\images\image240.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.001]
# val: WARNING  C:\Dataset\card\datasets\val\images\image335.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.056]
# val: WARNING  C:\Dataset\card\datasets\val\images\image339.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [       1.01]
# val: WARNING  C:\Dataset\card\datasets\val\images\image428.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.011]
# val: WARNING  C:\Dataset\card\datasets\val\images\image588.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.026]
# val: WARNING  C:\Dataset\card\datasets\val\images\image690.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.024]
# val: WARNING  C:\Dataset\card\datasets\val\images\image810.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
# val: WARNING  C:\Dataset\card\datasets\val\images\image935.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.018]
# Plotting labels to runs\obb\train6\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\obb\train6
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      2.64G     0.8041       1.49        1.8          4        640: 100%|██████████| 96/96 [00:17<00:00,  5.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  6.55it/s]
#                    all        386        386      0.988          1      0.993      0.923
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      2.52G     0.6554     0.5677      1.578          5        640: 100%|██████████| 96/96 [00:16<00:00,  5.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:02<00:00,  8.48it/s]
#                    all        386        386      0.995      0.998      0.995      0.906
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      2.51G       0.67      0.511      1.538          3        640: 100%|██████████| 96/96 [00:16<00:00,  5.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  8.26it/s]
#                    all        386        386      0.997          1      0.995      0.912
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      2.51G     0.6235     0.4759      1.541          6        640: 100%|██████████| 96/96 [00:15<00:00,  6.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  7.90it/s]
#                    all        386        386      0.982      0.997      0.994      0.938
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      2.51G     0.6171     0.4561       1.54          4        640: 100%|██████████| 96/96 [00:16<00:00,  5.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  7.99it/s]
#                    all        386        386      0.987      0.995      0.992      0.942
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      2.51G     0.6124     0.4577      1.541          3        640: 100%|██████████| 96/96 [00:16<00:00,  5.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  7.79it/s]
#                    all        386        386      0.997          1      0.995       0.94
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      2.51G     0.5559     0.4132      1.506          6        640: 100%|██████████| 96/96 [00:16<00:00,  5.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  7.97it/s]
#                    all        386        386      0.997          1      0.995      0.952
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      2
00:00,  5.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:03<00:00,  7.80it/s]
#                    all        386        386      0.996      0.997      0.995      0.981
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 21, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 31 epochs completed in 0.175 hours.
# Optimizer stripped from runs\obb\train6\weights\last.pt, 5.6MB
# Optimizer stripped from runs\obb\train6\weights\best.pt, 5.6MB
#
# Validating runs\obb\train6\weights\best.pt...
# Ultralytics 8.3.31  Python-3.10.15 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# YOLO11n-obb summary (fused): 257 layers, 2,653,918 parameters, 0 gradients, 6.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 25/25 [00:04<00:00,  6.20it/s]
#                    all        386        386      0.992          1      0.995      0.984
# Speed: 0.2ms preprocess, 1.8ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to runs\obb\train6

# %%
model = YOLO("runs/obb/train6/weights/best.pt")

# %%
def predict_corners(model, image_dir):
    result = model.predict(image_dir, imgsz=320, conf=0.5)[0]
    corner = result.obb[0].xyxyxyxy[0].cpu().numpy()
    return corner

# %%
def crop_image(raw_image, corners, expand_rate=0.05):
    corners = processing.expand_corners(raw_image.shape, corners, expand_rate)
    return processing.four_point_transform(raw_image, corners)

# %%
def extract_card(image, corners):
    if len(corners) < 4:
        return None
    corners = np.int32(corners)
    ordered_corners = processing.order_points(corners)
    return processing.four_point_transform(image, ordered_corners)

# %%
def auto_canny(image, sigma=0.33):
    # compute the median of the single channel pixel intensities
    v = np.median(image)

    # apply automatic Canny edge detection using the computed median
    lower = int(max(0, (1.0 - sigma) * v))
    upper = int(min(255, (1.0 + sigma) * v))
    edged = cv2.Canny(image, lower, upper, L2gradient = True)

    # return the edged image
    return edged

# %%
def find_intersections(lines, im):
    height, width = im.shape[:2]
    intersections = []
    for line1, line2 in itertools.permutations(lines, 2):
        rho1, theta1 = line1
        rho2, theta2 = line2
        a = [[np.cos(theta1), np.sin(theta1)], [np.cos(theta2), np.sin(theta2)]]
        b = [[rho1], [rho2]]
        try:
            # aX = b, solve for x
            x, y = np.round(np.linalg.solve(a, b))
            x, y = int(x[0]), int(y[0])
            if -width/10 < x < width + width/10 and -height/10 < y < height + height/10:
                if (x, y) not in intersections: intersections.append((x, y))

        except:
            pass
    return intersections

# %%
def apply_mask(image, mask):
    return cv2.bitwise_and(image, image, mask=mask)

# %%
def document_detect(cropped_image):
    try:
        im = cv2.bitwise_not(cropped_image)
        saturation = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        saturation = cv2.medianBlur(saturation, 15)
        edges = auto_canny(saturation, 0.5)

        mask = np.ones_like(edges)
        height, width = edges.shape[:2]
        cv2.rectangle(mask, (width//8, height//8), (width*7//8, height*7//8), 0, -1)
        edges = apply_mask(edges, mask)

        lines = cv2.HoughLines(edges, 1, np.pi/180, 100)
        lines = lines[:, 0, :]
        lines = [(line[0], line[1]) for line in lines]
        line_groups = []
        for line in lines:
            if np.pi/6 < line[1] < np.pi/3 or np.pi*2/3 < line[1] < np.pi*5/6:
                continue
            if line[1] > np.pi*5/6:
                line = (-line[0], line[1] - np.pi)
            for group in line_groups:
                mean_rho = np.mean([line[0] for line in group])
                mean_theta = np.mean([line[1] for line in group])
                if abs(line[0] - mean_rho) < 50 and abs(line[1] - mean_theta) < 0.3:
                    group.append(line)
                    break
            else:
                line_groups.append([line])
                
        new_lines = []
        for group in line_groups:
            rho = np.mean([line[0] for line in group])
            theta = np.mean([line[1] for line in group])
            new_lines.append((rho, theta))
                
        lines = new_lines
        intersection = find_intersections(lines, cropped_image)
        corners = intersection[:4]
        card = extract_card(cropped_image, corners)
    # quadrilaterals = docdetect.find_quadrilaterals(intersection)
    # frame = docdetect.draw(quadrilaterals, cropped_image)
    # return frame
    except:
        return None
    return card

# %%
image_dir = "C:/Dataset/card/temp/images/image57.png"

result = model.predict(image_dir, imgsz=320, conf=0.5)[0]
corner = result.obb[0].xyxyxyxy[0].cpu().numpy()

raw_image = cv2.imread(image_dir)
raw_image = cv2.cvtColor(raw_image, cv2.COLOR_BGR2RGB)
cropped = crop_image(raw_image, corner, expand_rate=0.1)
plt.imshow(cropped)
# Out:
# image 1/1 C:\Dataset\card\temp\images\image57.png: 320x192 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)

# %%
card = document_detect(cropped)
plt.imshow(card)

# %%
image_dir = "C:/Dataset/card/temp/images"
total = 0
card_fail = 0
output_dir = "../data/yolo_output"
card_dir = "../data/yolo_output/card"
cropped_dir = "../data/yolo_output/cropped"

# %%
shutil.rmtree(output_dir)
os.mkdir(output_dir)
os.mkdir(cropped_dir)
os.mkdir(card_dir)

for img_name in os.listdir(image_dir):
    total += 1
    raw_image = cv2.imread(image_dir + '/' + img_name)
    corners = predict_corners(model, image_dir + '/' + img_name)
    if corners is None:
        card_fail += 1
        continue
    cropped = crop_image(raw_image, corners, expand_rate=0.1)
    if cropped is not None:
        cv2.imwrite(cropped_dir + '/' + img_name, cropped)
        card = document_detect(cropped)
        if card is not None:
            cv2.imwrite(card_dir + '/' + img_name, card)
        else:
            card_fail += 1
    else:
        card_fail += 1
# Out:
# image 1/1 C:\Dataset\card\temp\images\image1.png: 320x192 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image10.png: 320x192 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image100.png: 320x192 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1000.png: 320x192 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1001.png: 320x192 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1002.png: 320x192 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1003.png: 320x192 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1004.png: 320x192 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1005.png: 320x192 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1006.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1007.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1008.png: 320x192 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1009.png: 320x192 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image101.png: 320x192 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1010.png: 320x192 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1011.png: 320x192 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1012.png: 320x192 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1013.png: 320x192 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1014.png: 320x192 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1015.png: 320x192 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1016.png: 320x192 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1017.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1018.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1019.png: 320x192 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image102.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1020.png: 320x192 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1021.png: 320x192 15.2ms
# Speed: 1.1ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1022.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1023.png: 320x192 14.3ms
# Speed: 1.3ms preprocess, 14.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1024.png: 320x192 15.2ms
# Speed: 1.1ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1025.png: 320x192 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1026.png: 320x192 14.7ms
# Speed: 1.0ms preprocess, 14.7ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1027.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1028.png: 320x192 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1029.png: 320x192 14.2ms
# Speed: 1.9ms preprocess, 14.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image103.png: 320x192 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1030.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1031.png: 320x192 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1032.png: 320x192 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1033.png: 320x192 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1034.png: 320x192 16.0ms
# Speed: 1.1ms preprocess, 16.0ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1035.png: 320x192 15.0ms
# Speed: 1.3ms preprocess, 15.0ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1036.png: 320x192 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1037.png: 320x192 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1038.png: 320x192 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1039.png: 320x192 15.3ms
# Speed: 0.9ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image104.png: 320x192 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1040.png: 320x192 15.2ms
# Speed: 1.2ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1041.png: 320x192 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1042.png: 320x192 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1043.png: 320x192 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1044.png: 320x192 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1045.png: 320x192 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1046.png: 320x192 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1047.png: 320x192 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1048.png: 320x192 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1049.png: 320x192 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image105.png: 320x192 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1050.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1051.png: 320x192 14.1ms
# Speed: 1.9ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1052.png: 320x192 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image1053.png: 320x192 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image1054.png: 320x192 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image
46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image926.png: 320x192 31.3ms
# Speed: 15.7ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image927.png: 320x192 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image928.png: 320x192 31.2ms
# Speed: 15.6ms preprocess, 31.2ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image929.png: 320x192 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image93.png: 320x192 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image930.png: 320x192 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image931.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image932.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image933.png: 320x192 15.6ms
# Speed: 15.6ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image934.png: 320x192 29.1ms
# Speed: 0.5ms preprocess, 29.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image935.png: 320x192 33.8ms
# Speed: 0.0ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image936.png: 320x192 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 17.8ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image937.png: 320x192 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image938.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image939.png: 320x192 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 16.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image94.png: 320x192 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image940.png: 320x192 34.0ms
# Speed: 15.5ms preprocess, 34.0ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image941.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image942.png: 320x192 37.1ms
# Speed: 11.0ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image943.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image944.png: 320x192 33.7ms
# Speed: 0.0ms preprocess, 33.7ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image945.png: 320x192 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image946.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 18.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image947.png: 320x192 42.3ms
# Speed: 0.5ms preprocess, 42.3ms inference, 17.8ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image948.png: 320x192 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 19.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image949.png: 320x192 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image95.png: 320x192 51.5ms
# Speed: 0.0ms preprocess, 51.5ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image950.png: 320x192 47.4ms
# Speed: 15.6ms preprocess, 47.4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image951.png: 320x192 42.2ms
# Speed: 0.0ms preprocess, 42.2ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image952.png: 320x192 43.5ms
# Speed: 0.0ms preprocess, 43.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image953.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image954.png: 320x192 45.2ms
# Speed: 0.0ms preprocess, 45.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image955.png: 320x192 62.7ms
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image956.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image957.png: 320x192 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image958.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 18.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image959.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image96.png: 320x192 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image960.png: 320x192 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image961.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 18.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image962.png: 320x192 61.0ms
# Speed: 0.0ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image963.png: 320x192 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image964.png: 320x192 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image965.png: 320x192 33.4ms
# Speed: 0.0ms preprocess, 33.4ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image966.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image967.png: 320x192 34.8ms
# Speed: 0.0ms preprocess, 34.8ms inference, 12.5ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image968.png: 320x192 78.4ms
# Speed: 46.4ms preprocess, 78.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image969.png: 320x192 31.6ms
# Speed: 0.0ms preprocess, 31.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image97.png: 320x192 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image970.png: 320x192 33.5ms
# Speed: 0.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image971.png: 320x192 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image972.png: 320x192 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image973.png: 320x192 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image974.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image975.png: 320x192 32.8ms
# Speed: 0.0ms preprocess, 32.8ms inference, 14.5ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image976.png: 320x192 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image977.png: 320x192 31.2ms
# Speed: 15.6ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image978.png: 320x192 31.1ms
# Speed: 0.0ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image979.png: 320x192 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image98.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image980.png: 320x192 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image981.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image982.png: 320x192 30.9ms
# Speed: 15.6ms preprocess, 30.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image983.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image984.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 18.3ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image985.png: 320x192 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image986.png: 320x192 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image987.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image988.png: 320x192 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image989.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image99.png: 320x192 15.5ms
# Speed: 15.7ms preprocess, 15.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\card\temp\images\image990.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image991.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image992.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image993.png: 320x192 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image994.png: 320x192 30.1ms
# Speed: 1.5ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image995.png: 320x192 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 17.3ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image996.png: 320x192 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 18.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image997.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 18.0ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image998.png: 320x192 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
# successed
#
# image 1/1 C:\Dataset\card\temp\images\image999.png: 320x192 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 192)
# successed

# %%
image_folder = "C:/Dataset/MIDV2020/dataset/photo/images"
output_folder = "D:/Coding/DATH/prediction"

# %%
def draw_lines(image, lines):
    for line in lines:
        rho, theta = line
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))
        cv2.line(image, (x1, y1), (x2, y2), (0, 0, 255), 2)
    return image

# %%
shutil.rmtree(output_folder)
os.mkdir(output_folder)

for image_dir in os.listdir(image_folder):
    os.mkdir(output_folder + '/' + image_dir)
    os.mkdir(output_folder + '/' + image_dir + '/card')
    os.mkdir(output_folder + '/' + image_dir + '/cropped')
    os.mkdir(output_folder + '/' + image_dir + '/line')
    os.mkdir(output_folder + '/' + image_dir + '/edge')
    for img_name in os.listdir(image_folder + '/' + image_dir):
        try:
            raw_image = cv2.imread(image_folder + '/' + image_dir + '/' + img_name)
            corners = predict_corners(model, image_folder + '/' + image_dir + '/' + img_name)
            cropped = crop_image(raw_image, corners, expand_rate=0.1)
            cv2.imwrite(output_folder + '/' + image_dir + '/cropped/' + img_name, cropped)
            # card = document_detect(cropped)
            im = cv2.bitwise_not(cropped)
            saturation = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            saturation = cv2.medianBlur(saturation, 15)
            edges = auto_canny(saturation, 0.5)
            cv2.imwrite(output_folder + '/' + image_dir + '/edge/' + img_name, edges)

            mask = np.ones_like(edges)
            height, width = edges.shape[:2]
            cv2.rectangle(mask, (width//8, height//8), (width*7//8, height*7//8), 0, -1)
            edges = apply_mask(edges, mask)

            lines = cv2.HoughLines(edges, 1, np.pi/180, 100)
            lines = lines[:, 0, :]
            lines = [(line[0], line[1]) for line in lines]
            line_groups = []
            for line in lines:
                if np.pi/6 < line[1] < np.pi/3 or np.pi*2/3 < line[1] < np.pi*5/6:
                    continue
                if line[1] > np.pi*5/6:
                    line = (-line[0], line[1] - np.pi)
                for group in line_groups:
                    mean_rho = np.mean([line[0] for line in group])
                    mean_theta = np.mean([line[1] for line in group])
                    if abs(line[0] - mean_rho) < 50 and abs(line[1] - mean_theta) < 0.3:
                        group.append(line)
                        break
                else:
                    line_groups.append([line])
                    
            new_lines = []
            for group in line_groups:
                rho = np.mean([line[0] for line in group])
                theta = np.mean([line[1] for line in group])
                new_lines.append((rho, theta))
                    
            lines = new_lines
            im = draw_lines(cropped.copy(), lines)
            cv2.imwrite(output_folder + '/' + image_dir + '/line/' + img_name, im)
            intersection = find_intersections(lines, cropped)
            corners = intersection[:4]
            card = extract_card(cropped, corners)
            cv2.imwrite(output_folder + '/' + image_dir + '/card/' + img_name, card)
        except:
            continue
# Out:
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\00.jpg: 320x192 (no detections), 19.7ms
# Speed: 2.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\01.jpg: 320x192 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 8.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\02.jpg: 320x192 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\03.jpg: 320x192 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\04.jpg: 320x192 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\05.jpg: 320x192 21.5ms
# Speed: 2.0ms preprocess, 21.5ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\06.jpg: 320x192 22.7ms
# Speed: 5.0ms preprocess, 22.7ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\07.jpg: 320x192 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\08.jpg: 320x192 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\09.jpg: 320x192 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\10.jpg: 320x192 (no detections), 23.5ms
# Speed: 1.5ms preprocess, 23.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\11.jpg: 320x192 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\12.jpg: 320x192 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\13.jpg: 320x192 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\14.jpg: 320x192 21.5ms
# Speed: 3.5ms preprocess, 21.5ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\15.jpg: 320x192 (no detections), 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\16.jpg: 320x192 (no detections), 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\17.jpg: 320x192 (no detections), 25.2ms
# Speed: 3.6ms preprocess, 25.2ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\18.jpg: 320x192 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id\19.jpg: 320x192 (no detections), 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\alb_id
ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\84.jpg: 320x192 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\85.jpg: 320x192 23.9ms
# Speed: 0.8ms preprocess, 23.9ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\86.jpg: 320x192 30.7ms
# Speed: 2.0ms preprocess, 30.7ms inference, 12.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\87.jpg: 320x192 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\88.jpg: 320x192 27.6ms
# Speed: 3.6ms preprocess, 27.6ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\89.jpg: 320x192 30.7ms
# Speed: 3.7ms preprocess, 30.7ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\90.jpg: 320x192 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 10.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\91.jpg: 320x192 30.5ms
# Speed: 2.0ms preprocess, 30.5ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\92.jpg: 320x192 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 9.9ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\93.jpg: 320x192 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 10.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\94.jpg: 320x192 28.3ms
# Speed: 2.6ms preprocess, 28.3ms inference, 12.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\95.jpg: 320x192 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\96.jpg: 320x192 (no detections), 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\97.jpg: 320x192 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 12.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\98.jpg: 320x192 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 11.8ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\aze_passport\99.jpg: 320x192 (no detections), 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\00.jpg: 320x192 23.8ms
# Speed: 4.1ms preprocess, 23.8ms inference, 12.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\01.jpg: 320x192 (no detections), 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\02.jpg: 320x192 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\03.jpg: 320x192 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\04.jpg: 320x192 (no detections), 26.6ms
# Speed: 3.5ms preprocess, 26.6ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\05.jpg: 320x192 24.2ms
# Speed: 2.5ms preprocess, 24.2ms inference, 11.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\06.jpg: 320x192 28.6ms
# Speed: 2.0ms preprocess, 28.6ms inference, 14.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\07.jpg: 320x192 33.4ms
# Speed: 2.6ms preprocess, 33.4ms inference, 14.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\08.jpg: 320x192 (no detections), 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\09.jpg: 320x192 (no detections), 24.8ms
# Speed: 1.6ms preprocess, 24.8ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\10.jpg: 320x192 30.6ms
# Speed: 2.5ms preprocess, 30.6ms inference, 9.9ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\11.jpg: 320x192 (no detections), 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\12.jpg: 320x192 (no detections), 28.8ms
# Speed: 1.6ms preprocess, 28.8ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\13.jpg: 320x192 (no detections), 24.0ms
# Speed: 1.7ms preprocess, 24.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\14.jpg: 320x192 37.5ms
# Speed: 3.0ms preprocess, 37.5ms inference, 13.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\15.jpg: 320x192 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 14.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\16.jpg: 320x192 (no detections), 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\17.jpg: 320x192 24.8ms
# Speed: 1.5ms preprocess, 24.8ms inference, 8.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\18.jpg: 320x192 (no detections), 26.0ms
# Speed: 1.9ms preprocess, 26.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\19.jpg: 320x192 24.0ms
# Speed: 6.6ms preprocess, 24.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\20.jpg: 320x192 (no detections), 25.0ms
# Speed: 2.3ms preprocess, 25.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\21.jpg: 320x192 (no detections), 23.6ms
# Speed: 2.5ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\22.jpg: 320x192 (no detections), 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\23.jpg: 320x192 (no detections), 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\24.jpg: 320x192 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\25.jpg: 320x192 (no detections), 31.4ms
# Speed: 1.0ms preprocess, 31.4ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\26.jpg: 320x192 (no detections), 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\27.jpg: 320x192 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 16.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\28.jpg: 320x192 (no detections), 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\29.jpg: 320x192 (no detections), 24.1ms
# Speed: 1.5ms preprocess, 24.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\30.jpg: 320x192 34.3ms
# Speed: 2.0ms preprocess, 34.3ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\31.jpg: 320x192 (no detections), 30.3ms
# Speed: 2.0ms preprocess, 30.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\32.jpg: 320x192 (no detections), 26.3ms
# Speed: 2.5ms preprocess, 26.3ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\33.jpg: 320x192 33.8ms
# Speed: 2.1ms preprocess, 33.8ms inference, 8.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\34.jpg: 320x192 (no detections), 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\35.jpg: 320x192 26.6ms
# Speed: 1.9ms preprocess, 26.6ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\36.jpg: 320x192 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 9.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\37.jpg: 320x192 22.5ms
# Speed: 2.6ms preprocess, 22.5ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\38.jpg: 320x192 20.9ms
# Speed: 3.2ms preprocess, 20.9ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\39.jpg: 320x192 41.2ms
# Speed: 2.2ms preprocess, 41.2ms inference, 16.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\40.jpg: 320x192 (no detections), 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\41.jpg: 320x192 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\42.jpg: 320x192 (no detections), 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\43.jpg: 320x192 (no detections), 29.3ms
# Speed: 1.6ms preprocess, 29.3ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\44.jpg: 320x192 (no detections), 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\45.jpg: 320x192 29.2ms
# Speed: 2.3ms preprocess, 29.2ms inference, 9.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\46.jpg: 320x192 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\47.jpg: 320x192 24.2ms
# Speed: 2.4ms preprocess, 24.2ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\48.jpg: 320x192 19.6ms
# Speed: 2.4ms preprocess, 19.6ms inference, 9.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\49.jpg: 320x192 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\50.jpg: 320x192 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 11.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\51.jpg: 320x192 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\52.jpg: 320x192 (no detections), 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\53.jpg: 320x192 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 9.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\54.jpg: 320x192 (no detections), 24.4ms
# Speed: 2.5ms preprocess, 24.4ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\55.jpg: 320x192 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\esp_id\56.jpg: 320x192 (no detections), 22.9ms
# ...
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\16.jpg: 320x192 (no detections), 23.9ms
# Speed: 2.1ms preprocess, 23.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\17.jpg: 320x192 (no detections), 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\18.jpg: 320x192 22.3ms
# Speed: 1.9ms preprocess, 22.3ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\19.jpg: 320x192 (no detections), 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\20.jpg: 320x192 (no detections), 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\21.jpg: 320x192 (no detections), 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\22.jpg: 320x192 (no detections), 23.1ms
# Speed: 3.1ms preprocess, 23.1ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\23.jpg: 320x192 (no detections), 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\24.jpg: 320x192 (no detections), 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\25.jpg: 320x192 (no detections), 23.5ms
# Speed: 2.0ms preprocess, 23.5ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\26.jpg: 320x192 (no detections), 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\27.jpg: 320x192 (no detections), 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\28.jpg: 320x192 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 10.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\29.jpg: 320x192 (no detections), 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\30.jpg: 320x192 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 9.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\31.jpg: 320x192 26.4ms
# Speed: 2.1ms preprocess, 26.4ms inference, 15.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\32.jpg: 320x192 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\33.jpg: 320x192 (no detections), 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\34.jpg: 320x192 (no detections), 23.3ms
# Speed: 1.5ms preprocess, 23.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\35.jpg: 320x192 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\36.jpg: 320x192 24.1ms
# Speed: 2.5ms preprocess, 24.1ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\37.jpg: 320x192 (no detections), 23.7ms
# Speed: 1.9ms preprocess, 23.7ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\38.jpg: 320x192 (no detections), 22.6ms
# Speed: 2.2ms preprocess, 22.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\39.jpg: 320x192 (no detections), 25.6ms
# Speed: 2.1ms preprocess, 25.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\40.jpg: 320x192 (no detections), 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\41.jpg: 320x192 (no detections), 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\42.jpg: 320x192 (no detections), 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\43.jpg: 320x192 (no detections), 25.5ms
# Speed: 2.4ms preprocess, 25.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\44.jpg: 320x192 (no detections), 24.1ms
# Speed: 2.6ms preprocess, 24.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\45.jpg: 320x192 26.2ms
# Speed: 2.6ms preprocess, 26.2ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\46.jpg: 320x192 (no detections), 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\47.jpg: 320x192 (no detections), 22.8ms
# Speed: 1.5ms preprocess, 22.8ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\48.jpg: 320x192 (no detections), 26.1ms
# Speed: 1.0ms preprocess, 26.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\49.jpg: 320x192 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 9.8ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\50.jpg: 320x192 (no detections), 20.8ms
# Speed: 1.9ms preprocess, 20.8ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\51.jpg: 320x192 (no detections), 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\52.jpg: 320x192 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 14.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\53.jpg: 320x192 (no detections), 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\54.jpg: 320x192 (no detections), 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\55.jpg: 320x192 23.3ms
# Speed: 1.0ms preprocess, 23.3ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\56.jpg: 320x192 (no detections), 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\57.jpg: 320x192 (no detections), 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\58.jpg: 320x192 (no detections), 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\59.jpg: 320x192 (no detections), 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\60.jpg: 320x192 (no detections), 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\61.jpg: 320x192 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\62.jpg: 320x192 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\63.jpg: 320x192 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\64.jpg: 320x192 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 8.9ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\65.jpg: 320x192 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\66.jpg: 320x192 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\67.jpg: 320x192 (no detections), 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\68.jpg: 320x192 (no detections), 24.5ms
# Speed: 1.5ms preprocess, 24.5ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\69.jpg: 320x192 23.7ms
# Speed: 1.2ms preprocess, 23.7ms inference, 11.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\70.jpg: 320x192 (no detections), 25.0ms
# Speed: 1.3ms preprocess, 25.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\71.jpg: 320x192 25.0ms
# Speed: 2.5ms preprocess, 25.0ms inference, 12.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\72.jpg: 320x192 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 9.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\73.jpg: 320x192 24.3ms
# Speed: 0.9ms preprocess, 24.3ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\74.jpg: 320x192 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\75.jpg: 320x192 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 12.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\76.jpg: 320x192 25.2ms
# Speed: 1.5ms preprocess, 25.2ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\77.jpg: 320x192 22.3ms
# Speed: 2.6ms preprocess, 22.3ms inference, 14.6ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\78.jpg: 320x192 22.9ms
# Speed: 2.5ms preprocess, 22.9ms inference, 8.9ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\79.jpg: 320x192 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 12.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\80.jpg: 320x192 (no detections), 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\81.jpg: 320x192 (no detections), 22.8ms
# Speed: 1.0ms preprocess, 22.8ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\82.jpg: 320x192 (no detections), 28.8ms
# Speed: 1.7ms preprocess, 28.8ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\83.jpg: 320x192 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\84.jpg: 320x192 (no detections), 24.4ms
# Speed: 0.5ms preprocess, 24.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\85.jpg: 320x192 (no detections), 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\86.jpg: 320x192 (no detections), 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\87.jpg: 320x192 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\88.jpg: 320x192 (no detections), 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\89.jpg: 320x192 (no detections), 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\90.jpg: 320x192 22.6ms
# Speed: 1.6ms preprocess, 22.6ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\91.jpg: 320x192 26.4ms
# Speed: 1.0ms preprocess, 26.4ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\92.jpg: 320x192 21.9ms
# Speed: 2.6ms preprocess, 21.9ms inference, 10.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\93.jpg: 320x192 (no detections), 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\94.jpg: 320x192 (no detections), 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\95.jpg: 320x192 (no detections), 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\96.jpg: 320x192 26.6ms
# Speed: 1.3ms preprocess, 26.6ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\97.jpg: 320x192 (no detections), 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\98.jpg: 320x192 (no detections), 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 192)
#
# image 1/1 C:\Dataset\MIDV2020\dataset\photo\images\svk_id\99.jpg: 320x192 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 12.1ms postprocess per image at shape (1, 3, 320, 192)

# %%
import matplotlib.pyplot as plt

# %%
x = [0.5, 0.6, 0.7, 0.8]
y = [0.88, 0.95, 0.96, 0.87]
plt.xticks(x)
plt.xlabel("threshold")
plt.ylabel("F1 score")
plt.plot(x, y)

# %%
from time import time
import os
import cv2

# %%
fake_templates = []
for fake_image in os.listdir("../fake_template"):
    fake_template = cv2.imread("../fake_template/" + fake_image)
    fake_template = cv2.resize(fake_template, (256, 256))
    fake_templates.append(fake_template)

# %%
image_dir = "C:/Dataset/card/datasets/train/train/images/image58.png"
raw_image = cv2.imread(image_dir)
corners = predict_corners(model, image_dir)
cropped = crop_image(raw_image, corners, expand_rate=0.1)
card = document_detect(cropped)
# Out:
# image 1/1 C:\Dataset\card\datasets\train\train\images\image58.png: 320x192 61.8ms
# Speed: 0.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 192)
